# %%
import os
import torch
import torch.nn as nn
from datasets import Dataset
from transformers import AutoModelForCausalLM, TrainingArguments, Trainer
from peft import get_peft_model, LoraConfig
from janus.janusflow.models import MultiModalityCausalLM, VLChatProcessor
from janus.utils.io import load_pil_images

os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "max_split_size_mb:128"
os.environ["CUDA_LAUNCH_BLOCKING"] = "1"
os.environ["TORCH_USE_CUDA_DSA"] = "1"

model_path = "deepseek-ai/JanusFlow-1.3B"
vl_chat_processor = VLChatProcessor.from_pretrained(model_path)
tokenizer = vl_chat_processor.tokenizer
# Out:
# /opt/conda/lib/python3.10/site-packages/torchvision/datapoints/__init__.py:12: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /opt/conda/lib/python3.10/site-packages/torchvision/transforms/v2/__init__.py:54: UserWarning: The torchvision.datapoints and torchvision.transforms.v2 namespaces are still Beta. While we do not expect major breaking changes, some APIs may still change according to user feedback. Please submit any feedback you may have in this issue: https://github.com/pytorch/vision/issues/6753, and you can also check out https://github.com/pytorch/vision/issues/7319 to learn more about the APIs that we suspect might involve future changes. You can silence this warning by calling torchvision.disable_beta_transforms_warning().
#   warnings.warn(_BETA_TRANSFORMS_WARNING)
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/image_processing_auto.py:590: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(
# Python version is above 3.10, patching the collections module.
# Python version is above 3.10, patching the collections module.
# /opt/conda/lib/python3.10/site-packages/transformers/models/auto/image_processing_auto.py:590: FutureWarning: The image_processor_class argument is deprecated and will be removed in v4.42. Please use `slow_image_processor_class`, or `fast_image_processor_class` instead
#   warnings.warn(
# preprocessor_config.json:   0%|          | 0.00/439 [00:00<?, ?B/s]
# Using a slow image processor as `use_fast` is unset and a slow processor was saved with this model. `use_fast=True` will be the default behavior in v4.48, even if the model was saved with a slow processor. This will result in minor differences in outputs. You'll still be able to use a slow processor with `use_fast=False`.
# tokenizer_config.json:   0%|          | 0.00/2.94k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/4.61M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/525 [00:00<?, ?B/s]
# processor_config.json:   0%|          | 0.00/369 [00:00<?, ?B/s]
# Some kwargs in processor config are unused and will not have any effect: image_end_tag, image_tag, image_gen_tag, mask_prompt, ignore_id, image_start_tag, sft_format, add_special_token, num_image_tokens.

# %%
class JanusForCausalLMWrapper(nn.Module):
    def __init__(self, model, tokenizer):
        super().__init__()
        self.model = model
        self.tokenizer = tokenizer
        if (hasattr(model, "language_model") and 
            hasattr(model.language_model, "get_input_embeddings") and 
            callable(model.language_model.get_input_embeddings)):
            self.embed = model.language_model.get_input_embeddings()
        else:
            raise NotImplementedError("The provided model does not have language_model.get_input_embeddings.")
    
    @property
    def config(self):
        if hasattr(self.model, "config"):
            return self.model.config
        elif hasattr(self.model, "language_model") and hasattr(self.model.language_model, "config"):
            return self.model.language_model.config
        else:
            raise AttributeError("No config attribute found in the model.")
    
    def prepare_inputs_for_generation(self, input_ids, **kwargs):
        return {"input_ids": input_ids, **kwargs}
    
    def _get_lm_head(self):
        if hasattr(self.model, "gen_head") and self.model.gen_head is not None:
            return self.model.gen_head
        elif hasattr(self.model, "lm_head") and self.model.lm_head is not None:
            return self.model.lm_head
        elif hasattr(self.model.language_model, "get_output_embeddings") and callable(self.model.language_model.get_output_embeddings):
            head = self.model.language_model.get_output_embeddings()
            if head is not None:
                return head
        hidden_dim = self.model.config.hidden_size
        vocab_size = len(self.tokenizer)
        print(f"Creating a new LM head with hidden_dim {hidden_dim} and vocab_size {vocab_size}.")
        new_head = nn.Linear(hidden_dim, vocab_size, bias=False).to(next(self.model.parameters()).device)
        nn.init.normal_(new_head.weight, mean=0.0, std=0.02)
        self.model.gen_head = new_head
        return new_head
    
    def forward(self, input_ids=None, attention_mask=None, labels=None, **kwargs):
        kwargs.pop("inputs_embeds", None)
        if input_ids is None:
            raise ValueError("input_ids must be provided")
        inputs_embeds = self.embed(input_ids)
        outputs = self.model.language_model.model(
            inputs_embeds=inputs_embeds,
            attention_mask=attention_mask,
            **kwargs
        )
        if isinstance(outputs, dict):
            hidden_states = outputs.get("last_hidden_state", outputs.get("hidden_states", outputs[0]))
        else:
            hidden_states = outputs[0]
        B, T, D = hidden_states.shape
        lm_head = self._get_lm_head()
        logits = lm_head(hidden_states.view(-1, D)).view(B, T, -1)
        lm_head_dim = logits.size(-1)
        tokenizer_vocab_size = len(self.tokenizer)
        if tokenizer_vocab_size != lm_head_dim:
            pass
            # print(f"Tokenizer vocab size {tokenizer_vocab_size} != LM head output dim {lm_head_dim}.")
            # print("Using LM head output dimension as the valid range.")
        vocab_size = lm_head_dim
        if labels is not None:
            shift_logits = logits[:, :-1, :].contiguous()
            shift_labels = labels[:, 1:].contiguous()
            # print(f"Effective vocabulary size (from LM head): {vocab_size}")
            # print(f"Max label value before replacement: {shift_labels.max().item()}")
            shift_labels = torch.where(
                shift_labels >= vocab_size,
                torch.tensor(-100, device=shift_labels.device),
                shift_labels
            )
            if torch.any(shift_labels >= vocab_size):
                raise ValueError(f"Invalid label values found: {shift_labels[shift_labels >= vocab_size]}")
            else:
                pass
                # print("All labels are within bounds.")
            loss_fct = torch.nn.CrossEntropyLoss(ignore_index=-100)
            loss = loss_fct(shift_logits.view(-1, shift_logits.size(-1)), shift_labels.view(-1))
            return {"loss": loss, "logits": logits, "hidden_states": hidden_states, "past_key_values": outputs.get("past_key_values", None)}
        else:
            return {"logits": logits, "hidden_states": hidden_states, "past_key_values": outputs.get("past_key_values", None)}
    
    def generate(self, input_ids, attention_mask=None, max_new_tokens=20, temperature=1.0):
        self.eval()
        generated = input_ids.clone()
        device = next(self.parameters()).device
        if attention_mask is not None:
            attn_mask = attention_mask.clone()
        else:
            attn_mask = None
        for _ in range(max_new_tokens):
            if attn_mask is not None:
                new_mask = torch.ones((attn_mask.size(0), 1), device=device, dtype=attn_mask.dtype)
                attn_mask = torch.cat([attn_mask, new_mask], dim=1)
            outputs = self.forward(input_ids=generated, attention_mask=attn_mask)
            logits = outputs["logits"]
            next_token_logits = logits[:, -1, :] / temperature
            next_token_probs = torch.softmax(next_token_logits, dim=-1)
            next_token = torch.multinomial(next_token_probs, num_samples=1)
            generated = torch.cat([generated, next_token], dim=1)
            if next_token.item() == self.tokenizer.eos_token_id:
                break
        return generated

vl_gpt = MultiModalityCausalLM.from_pretrained(model_path, trust_remote_code=True)
vl_gpt = vl_gpt.to(torch.bfloat16).cuda().eval()
base_model = vl_gpt.base_model
wrapped_model = JanusForCausalLMWrapper(base_model, tokenizer)
wrapped_model = wrapped_model.to(next(wrapped_model.parameters()).device)
# Out:
# The argument `trust_remote_code` is to be used with Auto classes. It has no effect here and is ignored.
# config.json:   0%|          | 0.00/1.60k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/4.09G [00:00<?, ?B/s]

# %%
import json

def main():
    # Open and parse the JSON file
    with open('dataset.json', 'r') as f:
        data = json.load(f)

    print(len(data))
    # Create a list to store the pairs
    pairs = []
    
    # For each entry, extract both English and Romanian pairs
    for entry in data:
        # English pair
        en_pair = {
            'instruction': entry['instruction']['en'],
            'response': entry['response']['en']
        }
        pairs.append(en_pair)
        
        # Romanian pair
        ro_pair = {
            'instruction': entry['instruction']['ro'],
            'response': entry['response']['ro']
        }
        pairs.append(ro_pair)
    
    return pairs

# %%
train_data = main()
# Out:
# 336

# %%
len(train_data)
# Out:
# 672

# %%
# %% [markdown]
# ## Prepare the Training Data
#
# We define two instruction–response pairs and format them as conversations using the SFT template.
#
# The formatting function creates a conversation with a `<|User|>` message and a `<|Assistant|>` reply.

# %% [code]
# Define our tiny training set

def format_conversation(instruction: str, response: str) -> str:
    conversation = [
        {"role": "<|User|>", "content": instruction},
        {"role": "<|Assistant|>", "content": response},
    ]
    # Apply the SFT template from the VLChatProcessor.
    # This returns a formatted text prompt that the model was originally trained with.
    formatted = vl_chat_processor.apply_sft_template_for_multi_turn_prompts(
        conversations=conversation,
        sft_format=vl_chat_processor.sft_format,
        system_prompt="",
    )
    return formatted

# Format each training example
formatted_texts = [format_conversation(item["instruction"], item["response"]) for item in train_data]

# %%
# %% [markdown]
# ## Tokenize the Data
#
# We tokenize the formatted conversations and set the `labels` equal to the input IDs for causal language modeling.
#
# (In a more advanced setup you might choose to mask parts of the prompt.)

# %% [code]
def tokenize_function(text):
    tokenized = tokenizer(text, truncation=True, max_length=64)
    # Replace pad token ids with -100 in the labels
    tokenized["labels"] = [
        -100 if token_id == tokenizer.pad_token_id else token_id
        for token_id in tokenized["input_ids"]
    ]
    return tokenized

# Tokenize each example
tokenized_data = [tokenize_function(txt) for txt in formatted_texts]

# Create a Hugging Face Dataset
dataset = Dataset.from_list(tokenized_data)

print("Number of training examples:", len(dataset))
# Out:
# Number of training examples: 672

# %%
lora_config = LoraConfig(
    r=8,
    lora_alpha=32,
    target_modules=["q_proj", "v_proj"],
    lora_dropout=0.1,
    bias="none",
    task_type="CAUSAL_LM",
)
model = get_peft_model(wrapped_model, lora_config)
print("Trainable parameters:")
model.print_trainable_parameters()

training_args = TrainingArguments(
    output_dir="./janus_peft_big",
    num_train_epochs=35,
    per_device_train_batch_size=1,
    learning_rate=5e-5,
    logging_steps=1,
    save_steps=10,
    fp16=True,
    report_to="none",
    deepspeed=None,
)
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
)
trainer.train()
# Out:
# Trainable parameters:
# trainable params: 1,572,864 || all params: 2,047,940,368 || trainable%: 0.0768
# [2025-02-08 14:14:01,469] [INFO] [real_accelerator.py:222:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# /opt/conda/compiler_compat/ld: cannot find -laio: No such file or directory
# collect2: error: ld returned 1 exit status
# /opt/conda/compiler_compat/ld: warning: libstdc++.so.6, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /opt/conda/compiler_compat/ld: warning: libm.so.6, needed by /usr/local/cuda/lib64/libcufile.so, not found (try using -rpath or -rpath-link)
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::runtime_error::~runtime_error()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__gxx_personality_v0@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::tellp()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::substr(unsigned long, unsigned long) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_replace_aux(unsigned long, unsigned long, unsigned long, char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `dlopen'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for bool@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_logic_error(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::~locale()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_end_catch@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__si_class_type_info@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::_M_stringbuf_init(std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator new[](unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_leak_hard()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(char const*, unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(std::string const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned short@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::resize(unsigned long, char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::str(std::string const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for char const*@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ctype<char>::_M_widen_init() const@GLIBCXX_3.4.11'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_invalid_argument(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_free_exception@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::Init::~Init()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::~basic_string()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_pure_virtual@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::flush()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for __cxxabiv1::__class_type_info@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_rethrow@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_M_dispose(std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_fstream<char, std::char_traits<char> >::~basic_fstream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::compare(char const*) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::locale::locale()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::chrono::_V2::system_clock::now()@GLIBCXX_3.4.19'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_ifstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Hash_bytes(void const*, unsigned long, unsigned long)@CXXABI_1.3.5'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::endl<char, std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long long>(long long)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::replace(unsigned long, unsigned long, unsigned long, char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for char*@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_Prime_rehash_policy::_M_need_rehash(unsigned long, unsigned long, unsigned long) const@GLIBCXX_3.4.18'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `dlclose'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long>(unsigned long)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::~ios_base()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::~__basic_file()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_guard_acquire@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<bool>(bool)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ios<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_filebuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator delete[](void*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::assign(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(unsigned long, char, std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_transfer(std::__detail::_List_node_base*, std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for std::exception@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream& std::istream::_M_extract<double>(double&)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_fstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::basic_ifstream(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(std::string const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator new(unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >::basic_stringstream(std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned int@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::append(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::find(char, unsigned long) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::put(char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for int@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_bad_alloc()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_thread_atexit@CXXABI_1.3.7'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_increment(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::~basic_ifstream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::Init::Init()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::swap(std::__detail::_List_node_base&, std::__detail::_List_node_base&)@GLIBCXX_3.4.15'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream::getline(char*, long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::basic_filebuf()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `VTT for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::cerr@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::find(char const*, unsigned long, unsigned long) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::str() const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for void*@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::assign(std::string const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(char const*, std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_ostringstream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_rebalance_for_erase(std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_hook(std::__detail::_List_node_base*)@GLIBCXX_3.4.15'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_List_node_base::_M_unhook()@GLIBCXX_3.4.15'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_istream<char, std::char_traits<char> >& std::getline<char, std::char_traits<char>, std::allocator<char> >(std::basic_istream<char, std::char_traits<char> >&, std::basic_string<char, std::char_traits<char>, std::allocator<char> >&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringbuf<char, std::char_traits<char>, std::allocator<char> >::_M_sync(char*, unsigned long, unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_iostream<char, std::char_traits<char> >::~basic_iostream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `log2f@GLIBC_2.2.5'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::exception::~exception()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_create(unsigned long, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__basic_file<char>::is_open() const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_M_mutate(unsigned long, unsigned long, unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `dlerror'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__detail::_Prime_rehash_policy::_M_next_bkt(unsigned long) const@GLIBCXX_3.4.18'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_istringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_istringstream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >::basic_ostringstream(std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::swap(std::string&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ostringstream<char, std::char_traits<char>, std::allocator<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::init(std::basic_streambuf<char, std::char_traits<char> >*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `dlsym'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_bad_cast()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ios<char, std::char_traits<char> >::clear(std::_Ios_Iostate)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `operator delete(void*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream::operator<<(int)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_S_empty_rep_storage@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::_Rep::_M_destroy(std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_ofstream<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_insert_and_rebalance(bool, std::_Rb_tree_node_base*, std::_Rb_tree_node_base*, std::_Rb_tree_node_base&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >::~basic_stringstream()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::end()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<long>(long)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream::get()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned long long@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::operator<< <std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::__ostream_insert<char, std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&, char const*, long)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ostream<char, std::char_traits<char> >& std::flush<char, std::char_traits<char> >(std::basic_ostream<char, std::char_traits<char> >&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::cout@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<unsigned long long>(unsigned long long)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::insert(unsigned long, char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_stringstream<char, std::char_traits<char>, std::allocator<char> >::basic_stringstream(std::string const&, std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::runtime_error::runtime_error(std::string const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<void const*>(void const*)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `vtable for std::basic_streambuf<char, std::char_traits<char> >@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_allocate_exception@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for void const*@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::reserve(unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_begin_catch@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for long@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::find(char const*, unsigned long) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::open(char const*, std::_Ios_Openmode)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::compare(std::string const&) const@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::istream::getline(char*, long, char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_istream<char, std::char_traits<char> >& std::getline<char, std::char_traits<char>, std::allocator<char> >(std::basic_istream<char, std::char_traits<char> >&, std::basic_string<char, std::char_traits<char>, std::allocator<char> >&, char)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::insert(unsigned long, char const*, unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::string::assign(char const*, unsigned long)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for unsigned char@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ios_base::ios_base()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_out_of_range(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_length_error(char const*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::__throw_system_error(int)@GLIBCXX_3.4.11'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::ostream& std::ostream::_M_insert<double>(double)@GLIBCXX_3.4.9'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `typeinfo for long long@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_string<char, std::char_traits<char>, std::allocator<char> >::basic_string(char const*, unsigned long, std::allocator<char> const&)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_ifstream<char, std::char_traits<char> >::close()@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_guard_release@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `__cxa_throw@CXXABI_1.3'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::_Rb_tree_decrement(std::_Rb_tree_node_base*)@GLIBCXX_3.4'
# /opt/conda/compiler_compat/ld: /usr/local/cuda/lib64/libcufile.so: undefined reference to `std::basic_filebuf<char, std::char_traits<char> >::~basic_filebuf()@GLIBCXX_3.4'
# collect2: error: ld returned 1 exit status
#     <div>
#
#       <progress value='23139' max='23520' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [23139/23520 1:16:11 < 01:15, 5.06 it/s, Epoch 34.43/35]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>4.394500</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.034200</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>3.257500</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>3.988000</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>3.937800</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>3.864600</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>4.007000</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>4.202700</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>3.377300</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>3.854600</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>3.479300</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>3.551000</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>3.838900</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>3.705700</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>3.898700</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>3.265400</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>4.135500</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>3.355500</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>3.897200</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>2.883000</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>3.970700</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>3.061700</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>3.816900</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>3.500200</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>4.238600</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>3.515900</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>4.153200</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>3.258600</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>3.813700</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>2.863500</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>3.129200</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>3.266900</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>3.383500</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>2.748000</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>4.275200</td>
#     </tr>
#     <tr>
#       <td>36</td>
#       <td>4.207900</td>
#     </tr>
#     <tr>
#       <td>37</td>
#       <td>3.322500</td>
#     </tr>
#     <tr>
#       <td>38</td>
#       <td>2.633200</td>
#     </tr>
#     <tr>
#       <td>39</td>
#       <td>2.738100</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>2.634800</td>
#     </tr>
#     <tr>
#       <td>41</td>
#       <td>2.382200</td>
#     </tr>
#     <tr>
#       <td>42</td>
#       <td>2.223100</td>
#     </tr>
#     <tr>
#       <td>43</td>
#       <td>3.555700</td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>2.955000</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>3.512600</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>2.766400</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>3.098400</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>3.465500</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1.829200</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>2.944900</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>2.239600</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>3.156400</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>2.349300</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>2.468400</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>2.511300</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>2.712300</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>3.482700</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>2.470700</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>2.316900</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>2.610100</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1.829700</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>3.129300</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>2.470400</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>2.705200</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>2.576400</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>3.100600</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>3.147800</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>3.361800</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>3.707900</td>
#     </tr>
#     <tr>
#       <td>70</td>
#       <td>3.261900</td>
#     </tr>
#     <tr>
#       <td>71</td>
#       <td>3.653000</td>
#     </tr>
#     <tr>
#       <td>72</td>
#       <td>1.727500</td>
#     </tr>
#     <tr>
#       <td>73</td>
#       <td>1.671400</td>
#     </tr>
#     <tr>
#       <td>74</td>
#       <td>3.859800</td>
#     </tr>
#     <tr>
#       <td>75</td>
#       <td>2.479300</td>
#     </tr>
#     <tr>
#       <td>76</td>
#       <td>2.168100</td>
#     </tr>
#     <tr>
#       <td>77</td>
#       <td>2.609400</td>
#     </tr>
#     <tr>
#       <td>78</td>
#       <td>1.642600</td>
#     </tr>
#     <tr>
#       <td>79</td>
#       <td>2.664300</td>
#     </tr>
#     <tr>
#       <td>80</td>
#       <td>2.714800</td>
#     </tr>
#     <tr>
#       <td>81</td>
#       <td>2.225100</td>
#     </tr>
#     <tr>
#       <td>82</td>
#       <td>2.869900</td>
#     </tr>
#     <tr>
#       <td>83</td>
#       <td>1.613600</td>
#     </tr>
#     <tr>
#       <td>84</td>
#       <td>2.092800</td>
#     </tr>
#     <tr>
#       <td>85</td>
#       <td>2.802500</td>
#     </tr>
#     <tr>
#       <td>86</td>
#       <td>2.592900</td>
#     </tr>
#     <tr>
#       <td>87</td>
#       <td>2.753800</td>
#     </tr>
#     <tr>
#       <td>88</td>
#       <td>2.623100</td>
#     </tr>
#     <tr>
#       <td>89</td>
#       <td>2.749500</td>
#     </tr>
#     <tr>
#       <td>90</td>
#       <td>2.792000</td>
#     </tr>
#     <tr>
#       <td>91</td>
#       <td>3.057600</td>
#     </tr>
#     <tr>
#       <td>92</td>
#       <td>3.668700</td>
#     </tr>
#     <tr>
#       <td>93</td>
#       <td>1.605300</td>
#     </tr>
#     <tr>
#       <td>94</td>
#       <td>1.942800</td>
#     </tr>
#     <tr>
#       <td>95</td>
#       <td>2.559100</td>
#     </tr>
#     <tr>
#       <td>96</td>
#       <td>2.785800</td>
#     </tr>
#     <tr>
#       <td>97</td>
#       <td>2.247900</td>
#     </tr>
#     <tr>
#       <td>98</td>
#       <td>1.999400</td>
#     </tr>
#     <tr>
#       <td>99</td>
#       <td>2.614400</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>2.232300</td>
#     </tr>
#     <tr>
#       <td>101</td>
#       <td>1.998400</td>
#     </tr>
#     <tr>
#       <td>102</td>
#       <td>1.732700</td>
#     </tr>
#     <tr>
#       <td>103</td>
#       <td>2.817800</td>
#     </tr>
#     <tr>
#       <td>104</td>
#       <td>2.371800</td>
#     </tr>
#     <tr>
#       <td>105</td>
#       <td>3.223300</td>
#     </tr>
#     <tr>
#       <td>106</td>
#       <td>2.248900</td>
#     </tr>
#     <tr>
#       <td>107</td>
#       <td>1.862400</td>
#     </tr>
#     <tr>
#       <td>108</td>
#       <td>3.221200</td>
#     </tr>
#     <tr>
#       <td>109</td>
#       <td>3.025700</td>
#     </tr>
#     <tr>
#       <td>110</td>
#       <td>1.796500</td>
#     </tr>
#     <tr>
#       <td>111</td>
#       <td>2.348500</td>
#     </tr>
#     <tr>
#       <td>112</td>
#       <td>2.317300</td>
#     </tr>
#     <tr>
#       <td>113</td>
#       <td>2.628600</td>
#     </tr>
#     <tr>
#       <td>114</td>
#       <td>2.091300</td>
#     </tr>
#     <tr>
#       <td>115</td>
#       <td>2.699700</td>
#     </tr>
#     <tr>
#       <td>116</td>
#       <td>2.382100</td>
#     </tr>
#     <tr>
#       <td>117</td>
#       <td>1.584800</td>
#     </tr>
#     <tr>
#       <td>118</td>
#       <td>1.168400</td>
#     </tr>
#     <tr>
#       <td>119</td>
#       <td>2.745000</td>
#     </tr>
#     <tr>
#       <td>120</td>
#       <td>1.422700</td>
#     </tr>
#     <tr>
#       <td>121</td>
#       <td>1.774700</td>
#     </tr>
#     <tr>
#       <td>122</td>
#       <td>2.253600</td>
#     </tr>
#     <tr>
#       <td>123</td>
#       <td>1.355000</td>
#     </tr>
#     <tr>
#       <td>124</td>
#       <td>2.022100</td>
#     </tr>
#     <tr>
#       <td>125</td>
#       <td>1.982100</td>

# %%
adapter_save_path = "./janus_peft_finetuned_big_1"
model.save_pretrained(adapter_save_path)
print(f"Adapter saved to {adapter_save_path}")
# Out:
# Adapter saved to ./janus_peft_finetuned_big_1

# %%
def generate_text(prompt: str, max_new_tokens: int = 100, temperature: float = 0.7) -> str:
    inputs = tokenizer(prompt, return_tensors="pt")
    device = next(wrapped_model.parameters()).device
    inputs = {k: v.to(device) for k, v in inputs.items()}
    generated_ids = wrapped_model.generate(
        input_ids=inputs["input_ids"],
        attention_mask=inputs.get("attention_mask", None),
        max_new_tokens=max_new_tokens,
        temperature=temperature,
    )
    return tokenizer.decode(generated_ids[0], skip_special_tokens=True)

test_instruction = "Cum mă autentific ca admin pentru a gestiona utilizatorii?"
test_formatted = format_conversation(test_instruction, "")
print("Test prompt (formatted):")
print(test_formatted)
print("\nGenerated response:")
print(generate_text(test_formatted))
# Out:
# Test prompt (formatted):
# <|User|>: Cum mă autentific ca admin pentru a gestiona utilizatorii?
#
# <|Assistant|>:
#
# Generated response:
# <|User|>: Cum mă autentific ca admin pentru a gestiona utilizatorii?
#
# <|Assistant|>: Accesează pagina de autentificare (http://supremejobs.test/auth), introdu emailul și parola de admin, apoi apasă pe 'Continue' pentru a-l conecta. Sistemul va verificaedată apoi apasă un badge dând rolul de admin, iar o notificare va confirma accesul.

# %%
train_data
# Out:
# [{'instruction': 'How do I log in as an admin to manage users?',
#   'response': "Visit the login page (http://supremejobs.test/auth), enter your admin email and password, then click 'Continue'. Once logged in, you'll be directed to your admin dashboard where you can manage users."},
#  {'instruction': 'Cum mă autentific ca admin pentru a gestiona utilizatorii?',
#   'response': "Accesează pagina de autentificare (http://supremejobs.test/auth), introdu emailul și parola de admin, apoi apasă 'Continue'. Odată autentificat, vei fi direcționat către dashboard-ul de admin, unde poți gestiona utilizatorii."},
#  {'instruction': 'How do I open the Add Admin User form?',
#   'response': "After logging in, navigate to the user management section by clicking on the 'Add Admin User' link. This will open the form for creating a new admin user."},
#  {'instruction': 'Cum deschid formularul de adăugare a unui utilizator admin?',
#   'response': "După autentificare, mergi la secțiunea de administrare a utilizatorilor și apasă pe linkul 'Add Admin User'. Aceasta va deschide formularul pentru a crea un nou utilizator admin."},
#  {'instruction': 'How do I fill out the Add User form?',
#   'response': "Enter the required details in the form fields, such as the user's first name, last name, and a unique email address. Ensure the email you provide isn't already in use."},
#  {'instruction': 'Cum completez formularul de adăugare a unui utilizator?',
#   'response': 'Introdu detaliile cerute în câmpurile formularului, cum ar fi prenumele, numele și o adresă de email unică. Asigură-te că emailul introdus nu este deja folosit.'},
#  {'instruction': 'How can I grant a new user access to financial information?',
#   'response': "Before submitting the form, check the box labeled 'Allow user view financial information' if you want the user to have access to financial details."},
#  {'instruction': 'Cum pot acorda unui utilizator nou acces la informațiile financiare?',
#   'response': "Înainte de a trimite formularul, bifează caseta 'Allow user view financial information' dacă dorești ca utilizatorul să aibă acces la informații financiare."},
#  {'instruction': 'How do I submit the Add User form?',
#   'response': 'Once the form is completely filled out and the necessary options are selected, click the submit button. This will add the new user to your system.'},
#  {'instruction': 'Cum trimit formularul de adăugare a unui utilizator?',
#   'response': 'După ce formularul este completat și opțiunile necesare sunt selectate, apasă butonul de trimitere pentru a adăuga utilizatorul în sistem.'},
#  {'instruction': 'Will my actions be recorded after I add a user?',
#   'response': 'Yes, the system automatically logs your actions. You will see a confirmation message if the new user is added successfully.'},
#  {'instruction': 'Vor fi înregistrate acțiunile mele după ce adaug un utilizator?',
#   'response': 'Da, sistemul înregistrează automat acțiunile tale. Vei primi un mesaj de confirmare dacă utilizatorul a fost adăugat cu succes.'},
#  {'instruction': 'How do I access the user management page to remove a user?',
#   'response': 'After logging in as an admin, visit the user management page at http://supremejobs.test/admin-sj/users to view the list of users.'},
#  {'instruction': 'Cum accesez pagina de administrare a utilizatorilor pentru a elimina un utilizator?',
#   'response': 'După autentificarea ca admin, accesează pagina de administrare a utilizatorilor la http://supremejobs.test/admin-sj/users pentru a vizualiza lista de utilizatori.'},
#  {'instruction': 'How do I remove a user from the list?',
#   'response': "Find the user you want to remove and click the 'Remove' button next to their name."},
#  {'instruction': 'Cum elimin un utilizator din listă?',
#   'response': "Găsește utilizatorul pe care dorești să-l elimini și apasă pe butonul 'Remove' de lângă numele acestuia."},
#  {'instruction': 'How do I confirm the removal of a user?',
#   'response': "If prompted, click 'Remove' again to confirm that you want to delete the user."},
#  {'instruction': 'Cum confirm eliminarea unui utilizator?',
#   'response': "Dacă ți se solicită, apasă din nou pe 'Remove' pentru a confirma ștergerea utilizatorului."},
#  {'instruction': 'What should I do if something goes wrong during these processes?',
#   'response': 'If you encounter any issues, double-check the information you entered and try again. If the problem persists, please contact support for further assistance.'},
#  {'instruction': 'Ce ar trebui să fac dacă ceva nu merge bine în timpul acestor procese?',
#   'response': 'Dacă întâmpini probleme, verifică datele introduse și încearcă din nou. Dacă problema persistă, te rugăm să contactezi suportul pentru asistență suplimentară.'},
#  {'instruction': 'How do I log in as an admin to manage candidate profiles?',
#   'response': "Start by visiting the login page at http://supremejobs.test/auth. Enter your admin email and password, then click 'Continue'. Once logged in, you'll be taken to your admin dashboard."},
#  {'instruction': 'Cum mă autentific ca admin pentru a gestiona profilurile candidaților?',
#   'response': "Începe prin accesarea paginii de autentificare la http://supremejobs.test/auth. Introdu emailul și parola de admin, apoi apasă 'Continue'. După autentificare, vei fi direcționat către dashboard-ul de admin."},
#  {'instruction': 'How do I open the candidate creation form?',
#   'response': 'After logging in, navigate to the candidate creation section by visiting http://supremejobs.test/admin-sj/candidates/create. The candidate personal information form will be displayed.'},
#  {'instruction': 'Cum deschid formularul de creare a unui candidat?',
#   'response': 'După autentificare, mergi la secțiunea de creare a candidatului accesând http://supremejobs.test/admin-sj/candidates/create. Formularul de informații personale pentru candidat se va afișa.'},
#  {'instruction': "How do I fill in the candidate's basic personal details?",
#   'response': "Simply enter the candidate's first name and last name in the corresponding fields. For example, you might enter 'John' as the first name and 'Doe' as the last name."},
#  {'instruction': 'Cum completez detaliile personale de bază ale candidatului?',
#   'response': "Completează câmpurile corespunzătoare cu prenumele și numele candidatului. De exemplu, poți introduce 'John' ca prenume și 'Doe' ca nume."},
#  {'instruction': 'How do I provide unique contact details for the candidate?',
#   'response': "Fill in the phone number and email fields with unique values. The system may automatically generate unique identifiers, so ensure you follow the suggested format, like using '201-555-XXXX' for phone and a distinct email address."},
#  {'instruction': 'Cum introduc detalii de contact unice pentru candidat?',
#   'response': "Completează câmpurile pentru telefon și email cu valori unice. Sistemul poate genera automat identificatori unici, așa că asigură-te că folosești formatul sugerat, cum ar fi '201-555-XXXX' pentru telefon și o adresă de email distinctă."},
#  {'instruction': 'How do I submit the candidate information form?',
#   'response': "Once you've filled in all the required fields, click the 'Continue' button to submit the form. This action will move you to the next step, like uploading the candidate's resume."},
#  {'instruction': 'Cum trimit formularul cu informațiile candidatului?',
#   'response': "După ce ai completat toate câmpurile obligatorii, apasă butonul 'Continue' pentru a trimite formularul. Această acțiune te va duce la pasul următor, cum ar fi încărcarea CV-ului candidatului."},
#  {'instruction': "What happens after I submit the candidate's personal information?",
#   'response': "After submitting the form, you will be redirected to a new page where you can upload the candidate's resume, ensuring that the candidate profile is completed step by step."},
#  {'instruction': 'Ce se întâmplă după ce trimit informațiile personale ale candidatului?',
#   'response': 'După trimiterea formularului, vei fi redirecționat către o pagină nouă unde poți încărca CV-ul candidatului, asigurând astfel completarea profilului pas cu pas.'},
#  {'instruction': 'Do I need to worry about entering duplicate information?',
#   'response': "No, the system ensures that each candidate's contact details are unique. Just follow the guidelines for entering phone numbers and email addresses."},
#  {'instruction': 'Trebuie să îmi fac griji pentru introducerea de informații duplicate?',
#   'response': 'Nu, sistemul se asigură că detaliile de contact ale fiecărui candidat sunt unice. Urmează doar ghidul pentru introducerea numerelor de telefon și a adreselor de email.'},
#  {'instruction': 'What should I do if I experience issues while filling out the form?',
#   'response': 'If you run into any issues, double-check that all fields are filled correctly and try again. If problems persist, reach out to support for help.'},
#  {'instruction': 'Ce ar trebui să fac dacă întâmpin probleme la completarea formularului?',
#   'response': 'Dacă întâmpini probleme, verifică dacă toate câmpurile sunt completate corect și încearcă din nou. Dacă problema persistă, contactează suportul pentru asistență.'},
#  {'instruction': 'How do I log in as an admin to edit user details?',
#   'response': "Go to the login page (http://supremejobs.test/auth), enter your admin email and password, and click 'Continue'. This will take you to your admin dashboard."},
#  {'instruction': 'Cum mă autentific ca admin pentru a edita detaliile unui utilizator?',
#   'response': "Accesează pagina de autentificare (http://supremejobs.test/auth), introdu emailul și parola de admin, apoi apasă 'Continue'. Vei fi redirecționat către dashboard-ul de admin."},
#  {'instruction': 'How do I navigate to the user management section?',
#   'response': 'From the admin dashboard, click on the user management section to view the list of all users.'},
#  {'instruction': 'Cum ajung la secțiunea de administrare a utilizatorilor?',
#   'response': 'Din dashboard-ul de admin, dă clic pe secțiunea de administrare a utilizatorilor pentru a vedea lista completă a utilizatorilor.'},
#  {'instruction': 'How do I open the Edit User form?',
#   'response': "On the user management page, locate the user you wish to edit and click on the 'Edit' link next to their name. This opens the form where you can modify their details."},
#  {'instruction': 'Cum deschid formularul de editare a unui utilizator?',
#   'response': "Pe pagina de administrare a utilizatorilor, găsește utilizatorul pe care dorești să îl editezi și dă clic pe linkul 'Edit' de lângă numele acestuia. Formularul de editare se va deschide."},
#  {'instruction': "How do I update a user's details?",
#   'response': 'Simply enter the new details in the form fields. For example, update the first name, last name, and email address with the latest information.'},
#  {'instruction': 'Cum actualizez detaliile unui utilizator?',
#   'response': 'Completează câmpurile formularului cu noile informații. De exemplu, poți actualiza prenumele, numele și adresa de email cu datele corecte.'},
#  {'instruction': 'How do I save the changes after editing a user?',
#   'response': "After updating the details, click the submit button to save your changes. The system will process and update the user's information."},
#  {'instruction': 'Cum salvez modificările după editarea unui utilizator?',
#   'response': 'După ce ai actualizat detaliile, apasă butonul de trimitere pentru a salva modificările. Sistemul va procesa și actualiza informațiile utilizatorului.'},
#  {'instruction': 'What should I expect after saving the changes?',
#   'response': 'Once you save the changes, the updated information will be reflected in the user management list. You may receive a confirmation message indicating that the changes were successful.'},
#  {'instruction': 'Ce se întâmplă după salvarea modificărilor?',
#   'response': 'După salvarea modificărilor, informațiile actualizate vor apărea în lista de administrare a utilizatorilor. Este posibil să primești un mesaj de confirmare care indică faptul că modificările au fost efectuate cu succes.'},
#  {'instruction': 'What should I do if I encounter an error while editing a user?',
#   'response': 'If something goes wrong, review the information you entered and try again. If the issue persists, consider contacting support for further assistance.'},
#  {'instruction': 'Ce trebuie să fac dacă întâmpin o eroare în timpul editării unui utilizator?',
#   'response': 'Dacă apare o problemă, verifică informațiile introduse și încearcă din nou. Dacă problema persistă, contactează suportul pentru asistență suplimentară.'},
#  {'instruction': 'How do I log in as an admin to access my profile settings?',
#   'response': "Simply visit the login page, enter your admin email and password, then click 'Continue'. Once logged in, you'll be directed to your dashboard where you can access your account settings."},
#  {'instruction': 'Cum mă autentific ca admin pentru a accesa setările contului meu?',
#   'response': "Accesează pagina de autentificare, introdu emailul și parola de admin, apoi apasă pe 'Continue'. Odată autentificat, vei fi redirecționat către dashboard-ul tău, de unde poți accesa setările contului."},
#  {'instruction': 'How do I navigate to my account settings page?',
#   'response': 'From your admin dashboard, go to the account settings section. This can be done by clicking on the appropriate link or visiting the account settings URL directly.'},
#  {'instruction': 'Cum ajung la pagina de setări a contului meu?',
#   'response': 'Din dashboard-ul de admin, mergi la secțiunea de setări a contului. Poți face acest lucru dând clic pe linkul corespunzător sau accesând direct URL-ul de setări.'},
#  {'instruction': 'How do I access the change password functionality?',
#   'response': "Once you're on the account settings page, click on the 'Edit' option. This will open the area where you can update your password and other personal settings."},
#  {'instruction': 'Cum pot accesa funcția de schimbare a parolei?',
#   'response': "Odată ajuns pe pagina de setări a contului, dă clic pe opțiunea 'Edit'. Aceasta va deschide secțiunea unde poți actualiza parola și alte setări personale."},
#  {'instruction': 'How do I save my changes after updating my password?',
#   'response': "After making your changes, click on the submit or 'Save' button. If everything is correct, the system will update your information and you will remain on the account settings page."},
#  {'instruction': 'Cum salvez modificările după ce îmi actualizez parola?',
#   'response': "După ce ai făcut modificările, apasă pe butonul de trimitere sau 'Save'. Dacă totul este corect, sistemul îți va actualiza informațiile și vei rămâne pe pagina de setări a contului."},
#  {'instruction': 'What should I do if my changes are not applied?',
#   'response': 'If your changes do not seem to take effect, double-check that all required fields are filled correctly. If the issue continues, consider reaching out to support for further assistance.'},
#  {'instruction': 'Ce trebuie să fac dacă modificările nu sunt aplicate?',
#   'response': 'Dacă modificările nu se aplică, verifică dacă toate câmpurile obligatorii sunt completate corect. Dacă problema persistă, contactează suportul pentru asistență suplimentară.'},
#  {'instruction': 'How do I log in as a company user to create a campaign?',
#   'response': "Visit the login page at http://supremejobs.test/auth, enter your company credentials, and click 'Continue'. You'll then be directed to your company dashboard."},
#  {'instruction': 'Cum mă autentific ca utilizator de companie pentru a crea o campanie?',
#   'response': "Accesează pagina de autentificare la http://supremejobs.test/auth, introdu credențialele companiei și apasă 'Continue'. Vei fi redirecționat către dashboard-ul companiei."},
#  {'instruction': 'How do I access the campaign creation form?',
#   'response': 'From your dashboard, navigate to the campaign creation page by visiting http://supremejobs.test/company/campaigns/create. The campaign creation form will be displayed.'},
#  {'instruction': 'Cum accesez formularul de creare a campaniei?',
#   'response': 'Din dashboard-ul companiei, mergi la pagina de creare a campaniei accesând http://supremejobs.test/company/campaigns/create. Formularul pentru crearea campaniei va fi afișat.'},
#  {'instruction': 'How do I fill out the campaign form?',
#   'response': "Enter the required details such as the campaign title (e.g., 'Spring Sale Campaign') and area (e.g., 'Online Store'). Also, provide the start and end dates for your campaign."},
#  {'instruction': 'Cum completez formularul campaniei?',
#   'response': "Completează detaliile necesare, cum ar fi titlul campaniei (exemplu: 'Spring Sale Campaign') și domeniul (exemplu: 'Online Store'). De asemenea, introdu datele de început și de sfârșit ale campaniei."},
#  {'instruction': 'How do I set the campaign dates?',
#   'response': "Use the provided date fields to select the start and end dates. Some forms allow you to directly enter the date in 'YYYY-MM-DD' format."},
#  {'instruction': 'Cum stabilesc datele campaniei?',
#   'response': "Folosește câmpurile de dată pentru a selecta datele de început și sfârșit. Unele formulare permit introducerea directă a datei în formatul 'YYYY-MM-DD'."},
#  {'instruction': 'How do I attach an image to my campaign?',
#   'response': 'Click on the image attachment area to select and upload a file from your computer to be used as the campaign image.'},
#  {'instruction': 'Cum atașez o imagine campaniei mele?',
#   'response': 'Dă clic pe zona de atașare a imaginii pentru a selecta și încărca un fișier de pe computerul tău, care va fi folosit ca imagine a campaniei.'},
#  {'instruction': 'How do I select jobs to include in my campaign?',
#   'response': "Click on the 'Select' button to open the job selection interface. Scroll through the available job cards, select the ones you want by clicking on them, and then confirm your selection."},
#  {'instruction': 'Cum selectez joburile care vor fi incluse în campania mea?',
#   'response': "Apasă pe butonul 'Select' pentru a deschide interfața de selectare a joburilor. Derulează printre cardurile de joburi disponibile, selectează-le pe cele dorite făcând clic pe ele și apoi confirmă selecția."},
#  {'instruction': 'How do I submit my campaign?',
#   'response': 'After filling out the form and selecting the jobs, click the submit button to start your campaign. The system will process your input and create the campaign.'},
#  {'instruction': 'Cum trimit campania mea?',
#   'response': 'După completarea formularului și selectarea joburilor, apasă butonul de trimitere pentru a porni campania. Sistemul va procesa informațiile introduse și va crea campania.'},
#  {'instruction': 'What should I do if I encounter an issue while creating a campaign?',
#   'response': "If something doesn't work as expected, review the information you've entered to ensure it's correct. If issues persist, consider contacting support for further assistance."},
#  {'instruction': 'Ce trebuie să fac dacă întâmpin o problemă în crearea campaniei?',
#   'response': 'Dacă ceva nu funcționează conform așteptărilor, verifică informațiile introduse pentru a te asigura că sunt corecte. Dacă problema persistă, contactează suportul pentru asistență suplimentară.'},
#  {'instruction': 'How do I log in as a company user to invite candidates?',
#   'response': "Visit the login page at http://supremejobs.test/auth, enter your company email and password, and click 'Continue'. After logging in, you'll be directed to your company dashboard."},
#  {'instruction': 'Cum mă autentific ca utilizator de companie pentru a invita candidați?',
#   'response': "Accesează pagina de autentificare la http://supremejobs.test/auth, introdu emailul și parola companiei, apoi apasă 'Continue'. După autentificare, vei fi direcționat către dashboard-ul companiei."},
#  {'instruction': 'How do I access the candidates page?',
#   'response': 'From your dashboard, navigate to the candidates section. This page displays the list of available candidates.'},
#  {'instruction': 'Cum accesez pagina cu candidați?',
#   'response': 'Din dashboard-ul companiei, mergi la secțiunea de candidați. Această pagină afișează lista candidaților disponibili.'},
#  {'instruction': 'How do I select a candidate for invitation?',
#   'response': "On the candidates page, click the checkbox next to the candidate's name to mark them for invitation."},
#  {'instruction': 'Cum selectez un candidat pentru a-l invita?',
#   'response': 'Pe pagina de candidați, dă clic pe caseta de selectare de lângă numele candidatului pentru a-l marca pentru invitație.'},
#  {'instruction': 'How do I send an invitation to a candidate?',
#   'response': "After selecting a candidate, click the 'Invite candidates' button. This will send an invitation to the selected candidate(s)."},
#  {'instruction': 'Cum trimit o invitație unui candidat?',
#   'response': "După ce ai selectat un candidat, apasă pe butonul 'Invite candidates'. Aceasta va trimite o invitație candidatului (sau candidaților) selectați."},
#  {'instruction': 'How do I select additional candidates from the list?',
#   'response': 'Scroll down to the bottom of the candidates page where more candidate cards are shown. Click on the cards you wish to select to add them to your invitation list.'},
#  {'instruction': 'Cum selectez candidați suplimentari din listă?',
#   'response': 'Derulează până la partea de jos a paginii de candidați, unde sunt afișate mai multe carduri. Dă clic pe cardurile pe care dorești să le selectezi pentru a le adăuga la lista de invitații.'},
#  {'instruction': 'What should I do if I encounter an issue during the invitation process?',
#   'response': 'If you run into any issues, make sure that you have properly selected the candidate(s) and that your connection is stable. If problems persist, contact support for further help.'},
#  {'instruction': 'Ce trebuie să fac dacă întâmpin o problemă în procesul de invitație?',
#   'response': 'Dacă întâmpini probleme, asigură-te că ai selectat corect candidatul (candidații) și că conexiunea ta este stabilă. Dacă problema persistă, contactează suportul pentru asistență suplimentară.'},
#  {'instruction': 'How do I log in as a company user to create a job posting?',
#   'response': "Go to the login page at http://supremejobs.test/auth, enter your company email and password, and click 'Continue'. You will then be directed to your company dashboard."},
#  {'instruction': 'Cum mă autentific ca utilizator de companie pentru a crea un anunț de job?',
#   'response': "Accesează pagina de autentificare la http://supremejobs.test/auth, introdu emailul companiei și parola, apoi apasă 'Continue'. Vei fi direcționat către dashboard-ul companiei."},
#  {'instruction': 'How do I access the job creation form?',
#   'response': 'From your dashboard, navigate to the job creation page by visiting http://supremejobs.test/company/jobs/create/general-info. The form will load with fields for the basic job details.'},
#  {'instruction': 'Cum accesez formularul de creare a unui job?',
#   'response': 'Din dashboard-ul companiei, mergi la pagina de creare a jobului accesând http://supremejobs.test/company/jobs/create/general-info. Formularul se va încărca cu câmpuri pentru detaliile de bază ale jobului.'},
#  {'instruction': 'How do I fill in the basic job details?',
#   'response': "Enter the job title (e.g., 'Tehnician Cablu'), select the industry from the dropdown, provide the application deadline (e.g., 'Dec 10, 2024'), and specify the number of positions available."},
#  {'instruction': 'Cum completez detaliile de bază ale jobului?',
#   'response': "Introdu titlul jobului (de exemplu, 'Tehnician Cablu'), selectează industria din meniul dropdown, completează data limită pentru aplicații (ex: 'Dec 10, 2024') și specifică numărul de posturi disponibile."},
#  {'instruction': 'How do I choose the job type and location?',
#   'response': "Select the job type by clicking on the appropriate option (like 'Full-time' or 'Remote') and then enter the job location (e.g., 'Iernut, România'). Ensure that any input events for the location field are triggered automatically."},
#  {'instruction': 'Cum aleg tipul de job și locația?',
#   'response': "Selectează tipul de job dând clic pe opțiunea corespunzătoare (de exemplu, 'Full-time' sau 'Remote') și apoi introdu locația jobului (ex: 'Iernut, România'). Asigură-te că evenimentele de input pentru câmpul locație sunt declanșate corespunzător."},
#  {'instruction': 'How do I select the job promotion locations?',
#   'response': "Use the select2 dropdown to type in and choose promotion locations such as 'Europe', 'USA', and 'Worldwide'. After typing each location, press 'Enter' to select it."},
#  {'instruction': 'Cum aleg locațiile de promovare pentru job?',
#   'response': "Folosește dropdown-ul select2 pentru a introduce și selecta locații de promovare, cum ar fi 'Europe', 'USA' și 'Worldwide'. După ce tastezi fiecare locație, apasă 'Enter' pentru a o selecta."},
#  {'instruction': 'How do I submit the general job information?',
#   'response': "Once you have filled in all the required fields, click the 'Save & Continue' button. The system will verify the inputs and take you to the next step (role requirements)."},
#  {'instruction': 'Cum trimit informațiile generale despre job?',
#   'response': "După ce ai completat toate câmpurile obligatorii, apasă butonul 'Save & Continue'. Sistemul va verifica datele introduse și te va redirecționa către pasul următor (cerințele pentru rol)."},
#  {'instruction': 'How do I set the role requirements for the job?',
#   'response': "On the role requirements page, select the experience level (e.g., '3 years'), choose the required skills (like 'Time management' and 'Problem-solving'), and specify the work schedule. Then, click 'Save & Continue' to proceed."},
#  {'instruction': 'Cum completez cerințele pentru rolul jobului?',
#   'response': "Pe pagina de cerințe pentru rol, selectează nivelul de experiență (ex: '3 years'), alege abilitățile necesare (de exemplu, 'Time management' și 'Problem-solving') și specifică programul de lucru. Apoi, apasă 'Save & Continue' pentru a continua."},
#  {'instruction': 'How do I configure the pay and benefits details?',
#   'response': "On the pay and benefits page, choose the payment type and frequency, enter the minimum and maximum salary, and select the currency (e.g., USD). You can also set the compensation package and perks using the provided options. After that, click 'Save & Continue'."},
#  {'instruction': 'Cum configurez detaliile privind plata și beneficiile?',
#   'response': "Pe pagina de plată și beneficii, selectează tipul și frecvența plății, introdu salariul minim și maxim și alege moneda (ex: USD). De asemenea, poți configura pachetul de compensații și beneficiile folosind opțiunile disponibile. După aceea, apasă 'Save & Continue'."},
#  {'instruction': 'How do I add a job description?',
#   'response': "On the job description page, wait for the CKEditor iframe to load, then enter the job description directly in the editor (e.g., 'Aceasta este o descriere a postului în limba română.')."},
#  {'instruction': 'Cum adaug descrierea jobului?',
#   'response': "Pe pagina de descriere a jobului, așteaptă încărcarea editorului CKEditor (iframe-ul) și apoi completează descrierea jobului direct în editor (ex: 'Aceasta este o descriere a postului în limba română.')."},
#  {'instruction': 'How do I finalize and submit the job posting?',
#   'response': 'After filling in the job description, scroll to the submit button and click it. Follow any additional steps for company description or job settings until the job creation process is complete.'},
#  {'instruction': 'Cum finalizez și trimit anunțul de job?',
#   'response': 'După ce ai completat descrierea jobului, derulează până la butonul de trimitere și apasă-l. Urmează orice pași suplimentari pentru descrierea companiei sau setările jobului până când procesul de creare a jobului este finalizat.'},
#  {'instruction': 'What should I do if I encounter errors during the job creation process?',
#   'response': "If you see any error messages (e.g., 'This field is required'), review the corresponding fields and ensure that all information is entered correctly. If issues persist, contact support for further assistance."},
#  {'instruction': 'Ce trebuie să fac dacă întâmpin erori în procesul de creare a jobului?',
#   'response': "Dacă apar mesaje de eroare (ex: 'This field is required'), verifică câmpurile corespunzătoare și asigură-te că toate informațiile sunt completate corect. Dacă problema persistă, contactează suportul pentru asistență suplimentară."},
#  {'instruction': 'How do I log in as a candidate?',
#   'response': "Visit the login page, enter your candidate email and password, then click 'Continue'. You'll be redirected to the candidate dashboard, and when you're finished, simply log out."},
#  {'instruction': 'Cum mă autentific ca și candidat?',
#   'response': "Accesează pagina de autentificare, introdu emailul de candidat și parola, apoi apasă 'Continue'. Vei fi redirecționat către dashboard-ul candidatului, iar când termini, te poți deconecta."},
#  {'instruction': 'How do I log in as a company user?',
#   'response': "On the login page, use your company credentials and click 'Continue'. You'll then be taken to the company dashboard. Remember to log out after your session."},
#  {'instruction': 'Cum mă autentific ca utilizator de companie?',
#   'response': "Pe pagina de autentificare, folosește credențialele companiei și apasă 'Continue'. Vei fi redirecționat către dashboard-ul companiei. Nu uita să te deconectezi după sesiune."},
#  {'instruction': 'How do I log in as an admin?',
#   'response': "Enter the admin credentials on the login page and click 'Continue'. You'll be redirected to the admin dashboard, and you can log out once you're done."},
#  {'instruction': 'Cum mă autentific ca administrator?',
#   'response': "Introdu credențialele administratorului pe pagina de autentificare și apasă 'Continue'. Vei fi redirecționat către dashboard-ul administratorului, iar când termini, te poți deconecta."},
#  {'instruction': 'How do I log out after logging in?',
#   'response': "After you're done with your session, simply click the logout link or button to end your session safely."},
#  {'instruction': 'Cum mă deconectez după autentificare?',
#   'response': 'După ce îți închei sesiunea, dă clic pe linkul sau butonul de logout pentru a te deconecta în siguranță.'},
#  {'instruction': 'How do I access the candidate signup form?',
#   'response': 'Simply visit the candidate signup URL provided (for example, http://supremejobs.test/onboarding-candidate-signup1). The page will load a form with fields for your personal information.'},
#  {'instruction': 'Cum accesez formularul de înscriere pentru candidați?',
#   'response': 'Accesează URL-ul de înscriere pentru candidați (de exemplu, http://supremejobs.test/onboarding-candidate-signup1). Pagina va încărca un formular cu câmpuri pentru informațiile tale personale.'},
#  {'instruction': 'How do I fill in my personal details?',
#   'response': 'Enter your first name and last name in the respective fields. Make sure to check your spelling before proceeding.'},
#  {'instruction': 'Cum completez detaliile mele personale?',
#   'response': 'Introdu prenumele și numele în câmpurile corespunzătoare. Asigură-te că datele sunt corecte înainte de a continua.'},
#  {'instruction': 'How do I select my country from the dropdown?',
#   'response': 'Click on the country dropdown to open the list, scroll until you find your country (for example, Romania), and click to select it.'},
#  {'instruction': 'Cum selectez țara din meniul derulant?',
#   'response': 'Dă clic pe meniul derulant pentru țară, derulează până găsești țara dorită (de exemplu, România) și selecteaz-o.'},
#  {'instruction': 'How do I enter my phone number?',
#   'response': 'Type your phone number in the designated field. Make sure the number is correct and follows the expected format.'},
#  {'instruction': 'Cum introduc numărul de telefon?',
#   'response': 'Introdu numărul de telefon în câmpul special desemnat. Asigură-te că numărul este corect și respectă formatul cerut.'},
#  {'instruction': 'How do I provide my email address?',
#   'response': 'Enter your email address in the email field. Use a valid and active email so you can receive further communications.'},
#  {'instruction': 'Cum introduc adresa mea de email?',
#   'response': 'Introdu adresa ta de email în câmpul dedicat. Folosește o adresă validă și activă pentru a putea primi comunicări ulterioare.'},
#  {'instruction': 'How do I set and confirm my password?',
#   'response': 'Type your desired password in the password field and re-enter it in the confirmation field. Make sure both entries match exactly.'},
#  {'instruction': 'Cum îmi stabilesc și confirm parola?',
#   'response': 'Introdu parola dorită în câmpul de parolă și reintrodu-o în câmpul de confirmare. Asigură-te că ambele intrări sunt identice.'},
#  {'instruction': 'How do I confirm my age?',
#   'response': 'Scroll down to find the checkbox for confirming your age and click it to indicate that you are an adult.'},
#  {'instruction': 'Cum confirm că am vârsta necesară?',
#   'response': 'Derulează în jos pentru a găsi caseta de selectare pentru confirmarea vârstei și bifeaz-o pentru a indica că ești adult.'},
#  {'instruction': 'How do I agree to the terms and conditions?',
#   'response': 'Scroll to the terms and conditions section and check the box to show that you agree with the policies.'},
#  {'instruction': 'Cum accept termenii și condițiile?',
#   'response': 'Derulează până la secțiunea cu termenii și condițiile și bifează caseta pentru a arăta că ești de acord cu politica.'},
#  {'instruction': 'How do I submit the candidate signup form?',
#   'response': "After filling in all required fields and selecting the necessary checkboxes, click the 'Continue' button. You will then be redirected to a code validation page to complete your signup process."},
#  {'instruction': 'Cum trimit formularul de înscriere pentru candidați?',
#   'response': "După ce ai completat toate câmpurile necesare și ai bifat opțiunile cerute, apasă butonul 'Continue'. Vei fi redirecționat către pagina de validare a codului pentru a finaliza înscrierea."},
#  {'instruction': 'How do I access the company signup form?',
#   'response': 'Simply visit the company signup URL (e.g., http://supremejobs.test/onboarding-company-signup1). The page will load a form where you can start your company registration.'},
#  {'instruction': 'Cum accesez formularul de înscriere pentru companii?',
#   'response': 'Accesează URL-ul de înscriere pentru companii (de exemplu, http://supremejobs.test/onboarding-company-signup1). Pagina va încărca un formular în care poți începe înregistrarea companiei tale.'},
#  {'instruction': 'How do I enter my company name?',
#   'response': "Type your company name into the 'Company Name' field. This is the first step in creating your company profile."},
#  {'instruction': 'Cum introduc numele companiei?',
#   'response': "Introdu numele companiei în câmpul 'Company Name'. Acesta este primul pas în crearea profilului companiei tale."},
#  {'instruction': 'How do I provide my personal details for the company signup?',
#   'response': 'Fill in your first name and last name in the corresponding fields. This helps associate your personal identity with the company account.'},
#  {'instruction': 'Cum completez detaliile mele personale pentru înscrierea companiei?',
#   'response': 'Completează câmpurile pentru prenume și nume. Acest lucru ajută la asocierea identității tale personale cu contul companiei.'},
#  {'instruction': 'How do I select my country from the dropdown?',
#   'response': 'Click on the country dropdown to open the list. Scroll or search for your country (for example, Romania) and click on it to select it.'},
#  {'instruction': 'Cum selectez țara din meniul derulant?',
#   'response': 'Dă clic pe meniul derulant pentru țară pentru a deschide lista. Derulează sau caută țara dorită (de exemplu, România) și apasă pe ea pentru a o selecta.'},
#  {'instruction': 'How do I enter my contact information?',
#   'response': 'Fill in your phone number and email address in the designated fields. Ensure that you use a valid phone number and email so you can receive further notifications.'},
#  {'instruction': 'Cum introduc informațiile de contact?',
#   'response': 'Completează câmpurile pentru numărul de telefon și adresa de email. Asigură-te că folosești un număr de telefon și o adresă de email valide pentru a putea primi notificări ulterioare.'},
#  {'instruction': 'How do I set and confirm my password?',
#   'response': 'Enter your desired password in the password field and retype it in the confirmation field. Make sure both entries match exactly.'},
#  {'instruction': 'Cum îmi stabilesc și confirm parola?',
#   'response': 'Introdu parola dorită în câmpul de parolă și reintrodu-o în câmpul de confirmare. Asigură-te că ambele intrări sunt identice.'},
#  {'instruction': 'How do I authorize the creation of my company account?',
#   'response': "Scroll down to the checkbox labeled for authorization (e.g., 'authorized_to_create') and check it to confirm that you have permission to create the company account."},
#  {'instruction': 'Cum autorizez crearea contului companiei?',
#   'response': "Derulează în jos până la caseta de selectare pentru autorizare (de exemplu, 'authorized_to_create') și bifeaz-o pentru a confirma că ai permisiunea de a crea contul companiei."},
#  {'instruction': 'How do I agree to the terms and conditions?',
#   'response': 'Scroll further down to the terms and conditions section and check the box to agree to them. This is required to proceed with your signup.'},
#  {'instruction': 'Cum accept termenii și condițiile?',
#   'response': 'Derulează până la secțiunea cu termeni și condiții și bifează caseta pentru a le accepta. Acest pas este necesar pentru a continua înscrierea.'},
#  {'instruction': 'How do I submit the company signup form?',
#   'response': "After filling in all required fields and selecting the necessary checkboxes, click the 'Continue' button. You will then be redirected to the next step of the company signup process."},
#  {'instruction': 'Cum trimit formularul de înscriere pentru companii?',
#   'response': "După ce ai completat toate câmpurile obligatorii și ai bifat opțiunile necesare, apasă butonul 'Continue'. Vei fi redirecționat către pasul următor din procesul de înscriere pentru companii."},
#  {'instruction': 'How do I log in as a candidate?',
#   'response': "Visit the login page and enter your candidate credentials. Click 'Continue' to reach your dashboard."},
#  {'instruction': 'Cum mă autentific ca și candidat?',
#   'response': "Accesează pagina de autentificare și introdu credențialele tale de candidat. Apasă 'Continue' pentru a ajunge la dashboard-ul tău."},
#  {'instruction': 'How do I access my profile settings?',
#   'response': "Once you're logged in, navigate to your profile settings by clicking on the 'Settings' option from your dashboard."},
#  {'instruction': 'Cum accesez setările profilului meu?',
#   'response': "După autentificare, mergi la setările profilului dând clic pe opțiunea 'Settings' din dashboard-ul tău."},
#  {'instruction': 'How do I open the Change Password section?',
#   'response': "On the settings page, locate and click the 'Change Password' link. This will open the section where you can update your password."},
#  {'instruction': 'Cum accesez secțiunea de schimbare a parolei?',
#   'response': "Pe pagina de setări, găsește și dă clic pe link-ul 'Change Password'. Aceasta va deschide secțiunea în care îți poți actualiza parola."},
#  {'instruction': 'How do I update my password?',
#   'response': "In the Change Password section, enter your current password, then type your new password and confirm it. Finally, click the 'Submit' or 'Save' button to update your password."},
#  {'instruction': 'Cum îmi actualizez parola?',
#   'response': "În secțiunea de schimbare a parolei, introdu parola actuală, apoi tastează noua parolă și confirm-o. În final, apasă butonul 'Submit' sau 'Save' pentru a actualiza parola."},
#  {'instruction': 'What should I do if I encounter issues while changing my password?',
#   'response': "If you experience any difficulties, try refreshing the page or clearing your browser's cache. If the problem persists, please contact support for assistance."},
#  {'instruction': 'Ce fac dacă întâmpin probleme la schimbarea parolei?',
#   'response': 'Dacă întâmpini dificultăți, încearcă să reîncarci pagina sau să ștergi memoria cache a browserului. Dacă problema persistă, te rugăm să contactezi suportul pentru asistență.'},
#  {'instruction': 'How do I log in and access my candidate profile editing page?',
#   'response': "First, log in using your candidate credentials. Then navigate to your 'My Profile' section from the dashboard to begin editing your profile details."},
#  {'instruction': 'Cum mă autentific și accesez pagina de editare a profilului meu de candidat?',
#   'response': "Mai întâi, autentifică-te folosind credențialele de candidat. Apoi, din dashboard, accesează secțiunea 'My Profile' pentru a începe editarea detaliilor profilului."},
#  {'instruction': 'How do I update my contact information?',
#   'response': "Click the contact information icon or link on your profile page to open the contact info modal. Update your first name, last name, address, city, state, country, phone, and email, then click 'Save' to apply your changes."},
#  {'instruction': 'Cum îmi actualizez informațiile de contact?',
#   'response': "Dă clic pe pictograma sau link-ul de informații de contact din pagina profilului pentru a deschide fereastra modală. Actualizează prenumele, numele, adresa, orașul, județul, țara, telefonul și emailul, apoi apasă 'Save' pentru a salva modificările."},
#  {'instruction': 'How do I update my work experience details?',
#   'response': "Click on the 'Experience' link on your profile to open the work experience modal. Fill in your job title, employment type, company name, job location, and the dates of employment, then save your changes."},
#  {'instruction': 'Cum îmi actualizez detaliile despre experiența profesională?',
#   'response': "Dă clic pe link-ul 'Experience' din profil pentru a deschide fereastra modală a experienței profesionale. Completează titlul jobului, tipul de angajare, numele companiei, locația jobului și datele de angajare, apoi salvează modificările."},
#  {'instruction': 'How do I update my education details?',
#   'response': "Open the 'Education' modal by clicking the education link. Enter your school name, degree, field of study, country, and the start and end dates, then click 'Save' to update your education information."},
#  {'instruction': 'Cum îmi actualizez detaliile despre educație?',
#   'response': "Deschide fereastra modală 'Education' dând clic pe link-ul dedicat. Introdu numele instituției, titlul obținut, domeniul de studiu, țara și datele de început și finalizare, apoi apasă 'Save' pentru a actualiza informațiile despre educație."},
#  {'instruction': 'How do I update my language proficiency?',
#   'response': 'Click on the language editing option to open the language modal. Select your language and choose your proficiency level, then save your selection.'},
#  {'instruction': 'Cum îmi actualizez nivelul de competență lingvistică?',
#   'response': 'Dă clic pe opțiunea de editare a limbilor pentru a deschide fereastra modală. Selectează limba și nivelul de competență, apoi salvează selecția.'},
#  {'instruction': 'How do I update my military service details?',
#   'response': "Access the military service modal by clicking the corresponding link. Fill in details like country, branch, rank, service dates, and a description of your service, then click 'Save' to update the information."},
#  {'instruction': 'Cum îmi actualizez detaliile despre serviciul militar?',
#   'response': "Accesează fereastra modală pentru serviciul militar dând clic pe link-ul corespunzător. Completează detalii precum țara, ramura, gradul, datele de serviciu și o descriere a activității, apoi apasă 'Save' pentru a actualiza informațiile."},
#  {'instruction': 'How do I update my medical exam status?',
#   'response': "Open the medical exam modal from your profile, then check or uncheck the option indicating whether you've taken the exam as needed, and finally click 'Save' to confirm the update."},
#  {'instruction': 'Cum îmi actualizez starea examenului medical?',
#   'response': "Deschide fereastra modală pentru examenul medical din profil, apoi bifează sau debifează opțiunea care indică dacă ai susținut examenul, și în final apasă 'Save' pentru a confirma actualizarea."},
#  {'instruction': 'How do I update my relocation preferences?',
#   'response': "Click the relocation modal link to open the relocation options. Enable relocation by checking the option, then select whether you prefer 'Anywhere' or 'Near', choose specific countries if applicable, and save your choices."},
#  {'instruction': 'Cum îmi actualizez preferințele de relocare?',
#   'response': "Dă clic pe link-ul pentru modulul de relocare pentru a deschide opțiunile de relocare. Activează relocarea bifând opțiunea, apoi selectează dacă preferi 'Anywhere' sau 'Near', alege țările specifice dacă este cazul și salvează selecția."},
#  {'instruction': 'How do I update my job type preference?',
#   'response': "Access the job type modal by clicking its link. Adjust your job type selection (for example, toggle the 'Full-time' option) and click 'Save' to update your preference."},
#  {'instruction': 'Cum îmi actualizez preferința pentru tipul de job?',
#   'response': "Accesează fereastra modală pentru tipul de job dând clic pe link-ul aferent. Ajustează selecția tipului de job (de exemplu, activează sau dezactivează opțiunea 'Full-time') și apasă 'Save' pentru a actualiza preferința."},
#  {'instruction': 'How do I update my salary details?',
#   'response': "Open the salary modal from your profile. Enter your minimum base pay, select the appropriate currency, adjust the payment period (e.g., 'Per year'), and click 'Save' to finalize your salary details."},
#  {'instruction': 'Cum îmi actualizez detaliile despre salariu?',
#   'response': "Deschide fereastra modală pentru salariu din profilul tău. Introdu salariul de bază minim, selectează moneda potrivită, ajustează perioada de plată (de exemplu, 'Per year') și apasă 'Save' pentru a finaliza detaliile despre salariu."},
#  {'instruction': 'How do I log in as a company user to edit my profile?',
#   'response': "Visit the login page, enter your company email and password, and click 'Continue' to access your company dashboard."},
#  {'instruction': 'Cum mă autentific ca utilizator de companie pentru a edita profilul?',
#   'response': "Accesează pagina de autentificare, introdu emailul și parola companiei, apoi apasă 'Continue' pentru a ajunge la dashboard-ul companiei."},
#  {'instruction': 'How do I navigate to my company profile page?',
#   'response': "From your dashboard, click on the 'Company Profile' link or visit the designated profile page to view your company information."},
#  {'instruction': 'Cum ajung la pagina profilului companiei?',
#   'response': "Din dashboard-ul companiei, dă clic pe link-ul 'Company Profile' sau accesează pagina destinată pentru a vedea informațiile companiei."},
#  {'instruction': 'How do I access the profile editing section?',
#   'response': "Click on the 'Edit Profile' link or button to open the profile editing interface, where you can update your company details."},
#  {'instruction': 'Cum accesez secțiunea de editare a profilului?',
#   'response': "Apasă pe link-ul sau butonul 'Edit Profile' pentru a deschide interfața de editare a profilului și a actualiza informațiile companiei."},
#  {'instruction': 'How do I update my company contact information?',
#   'response': "Open the contact information modal by clicking on the relevant icon. Then, update fields such as company name, address, contact person’s first and last names, phone number, and email address. Finally, click 'Save' to apply your changes."},
# ...
#  {'instruction': "Ce face funcția 'save' pentru CV-uri?",
#   'response': "Funcția de salvare comută statusul de 'saved' al unui CV pentru compania ta. Dacă CV-ul nu este salvat, acesta este marcat ca salvat; dacă este deja salvat, se poate dezactiva salvarea. Acest lucru îți permite să marchezi CV-uri pentru revizuire ulterioară."},
#  {'instruction': 'How do I view search results when filtering resumes?',
#   'response': "After applying filters using keywords or location parameters, the system displays a paginated list of candidate profiles that match your search criteria. You can also preview a candidate's detailed profile from this list."},
#  {'instruction': 'Cum vizualizez rezultatele căutării când filtrez CV-urile?',
#   'response': 'După aplicarea filtrelor folosind cuvinte cheie sau parametri de locație, sistemul afișează o listă paginată de profiluri de candidați care corespund criteriilor de căutare. De asemenea, poți previzualiza profilul detaliat al unui candidat din această listă.'},
#  {'instruction': 'How does the system handle resume search sorting and pagination?',
#   'response': 'The system sorts search results by creation date (ascending or descending) based on your selection. It also applies pagination to help you navigate through a large number of candidate profiles efficiently.'},
#  {'instruction': 'Cum gestionează sistemul sortarea și paginarea în căutarea CV-urilor?',
#   'response': 'Sistemul sortează rezultatele căutării după data creării (ascendent sau descendent) în funcție de selecția ta. De asemenea, aplică paginare pentru a te ajuta să navighezi eficient printre un număr mare de profiluri de candidați.'},
#  {'instruction': 'How do I purchase or save a resume from the search results?',
#   'response': 'Within the search results, you can choose to either purchase a resume—if you have sufficient credits—or toggle its saved status. The system updates the resume record accordingly and returns a confirmation message.'},
#  {'instruction': 'Cum cumpăr sau salvez un CV din rezultatele căutării?',
#   'response': 'În rezultatele căutării, poți alege fie să cumperi un CV—dacă ai suficiente credite—, fie să comuți statusul de salvare. Sistemul actualizează înregistrarea CV-ului și îți returnează un mesaj de confirmare.'},
#  {'instruction': 'How do I create a new job posting draft?',
#   'response': 'Begin by navigating to the job creation page (Step 1). Fill in the required fields such as job title, industry, deadline, number of positions, employment type, location, and relevant job performance details. Once completed, save the draft to store it in your session.'},
#  {'instruction': 'Cum creez un draft nou pentru un anunț de job?',
#   'response': 'Începe prin accesarea paginii de creare a jobului (Pasul 1). Completează câmpurile obligatorii precum titlul jobului, industria, termenul limită, numărul de posturi, tipul de angajare, locația și detaliile legate de modul de desfășurare a jobului. După completare, salvează draftul pentru a-l stoca în sesiunea ta.'},
#  {'instruction': 'How do I update job requirements after saving a draft?',
#   'response': "Proceed to Step 2 where you can update the job requirements. Enter the candidate's experience level, list the required skills, and define the work schedule. Save your changes to update the draft."},
#  {'instruction': 'Cum actualizez cerințele jobului după ce am salvat un draft?',
#   'response': 'Treci la Pasul 2 unde poți actualiza cerințele jobului. Introdu nivelul de experiență al candidatului, listează abilitățile necesare și stabilește programul de lucru. Salvează modificările pentru a actualiza draftul.'},
#  {'instruction': 'How do I add compensation and benefits details to a job posting?',
#   'response': 'In Step 3, you will provide compensation details. Enter the minimum and maximum salary, select the currency, and specify any compensation packages and perks or benefits. Save the information to update your draft.'},
#  {'instruction': 'Cum adaug detalii despre compensații și beneficii la un anunț de job?',
#   'response': 'În Pasul 3, vei introduce detaliile despre compensații. Completează salariul minim și maxim, selectează moneda și specifică eventualele pachete de compensații și beneficii. Salvează informațiile pentru a actualiza draftul.'},
#  {'instruction': 'How do I include a job description and a company description?',
#   'response': 'After finalizing compensation details, proceed to Step 4 to add a detailed job description. Then, in Step 5, provide the company description. Ensure you save each step to preserve the information in your draft.'},
#  {'instruction': 'Cum adaug descrierea jobului și descrierea companiei?',
#   'response': 'După ce finalizezi detaliile de compensații, treci la Pasul 4 pentru a adăuga o descriere detaliată a jobului. Apoi, în Pasul 5, completează descrierea companiei. Asigură-te că salvezi fiecare pas pentru a păstra informațiile în draft.'},
#  {'instruction': 'How do I publish my job posting after completing the draft?',
#   'response': "In Step 6, review all job details, including notification settings and the start date for the posting. When you're ready, publish the job by selecting the 'save and publish' option. This action will make the job live and trigger notifications to candidates and company managers."},
#  {'instruction': 'Cum public jobul după ce am completat draftul?',
#   'response': "În Pasul 6, verifică toate detaliile jobului, inclusiv setările de notificare și data de începere a postării. Când ești gata, publică jobul selectând opțiunea 'salvează și publică'. Această acțiune va face ca jobul să devină activ și va declanșa notificări către candidați și managerii companiei."},
#  {'instruction': 'What should I do if I want to discard a job posting draft?',
#   'response': "If you decide to discard the job posting, use the 'discard job' option. This will delete the current draft from your session and abandon the posting process. A confirmation message will indicate that the draft has been successfully discarded."},
#  {'instruction': 'Ce fac dacă doresc să renunț la un draft de job?',
#   'response': "Dacă decizi să renunți la anunțul de job, folosește opțiunea 'renunță la draft'. Aceasta va șterge draftul curent din sesiune și va abandona procesul de postare. Un mesaj de confirmare va indica că draftul a fost renunțat cu succes."},
#  {'instruction': 'What is the purpose of the ConfirmPasswordController?',
#   'response': 'The ConfirmPasswordController handles password confirmation requests, ensuring that authenticated users re-enter their password before accessing sensitive parts of the application. It leverages the built-in ConfirmsPasswords trait for its functionality.'},
#  {'instruction': 'Care este scopul controller-ului ConfirmPasswordController?',
#   'response': 'ConfirmPasswordController gestionează cererile de confirmare a parolei, asigurându-se că utilizatorii autentificați își reintroduc parola înainte de a accesa secțiuni sensibile ale aplicației. Acesta folosește trait-ul integrat ConfirmsPasswords pentru funcționalitate.'},
#  {'instruction': 'How can I change the redirect path after a successful password confirmation?',
#   'response': 'You can change the redirect path by updating the $redirectTo property in the ConfirmPasswordController. By default, it is set to RouteServiceProvider::HOME.'},
#  {'instruction': 'Cum pot modifica calea de redirecționare după confirmarea parolei?',
#   'response': 'Poți modifica calea de redirecționare actualizând proprietatea $redirectTo din ConfirmPasswordController. În mod implicit, aceasta este setată la RouteServiceProvider::HOME.'},
#  {'instruction': 'Who can access the ConfirmPasswordController?',
#   'response': "Access to the ConfirmPasswordController is restricted to authenticated users only, as the controller applies the 'auth' middleware in its constructor."},
#  {'instruction': 'Cine poate accesa ConfirmPasswordController?',
#   'response': "Accesul la ConfirmPasswordController este restricționat doar pentru utilizatorii autentificați, deoarece controller-ul aplică middleware-ul 'auth' în constructor."},
#  {'instruction': 'What is the purpose of the ForgotPasswordController?',
#   'response': 'The ForgotPasswordController is responsible for handling password reset emails. It uses the SendsPasswordResetEmails trait to send notifications to users who have forgotten their passwords.'},
#  {'instruction': 'Care este scopul ForgotPasswordController?',
#   'response': 'ForgotPasswordController se ocupă de trimiterea email-urilor pentru resetarea parolei. Folosește trait-ul SendsPasswordResetEmails pentru a trimite notificări către utilizatorii care și-au uitat parola.'},
#  {'instruction': 'How is the redirect after sending the password reset link configured?',
#   'response': "The controller overrides the sendResetLinkResponse method. In this method, it stores the user's email in the session and then redirects the user to the '/reset-password-confirmation' page."},
#  {'instruction': 'Cum este configurată redirecționarea după trimiterea link-ului de resetare a parolei?',
#   'response': "Controllerul suprascrie metoda sendResetLinkResponse. În această metodă, se salvează emailul utilizatorului în sesiune și apoi se redirecționează utilizatorul către pagina '/reset-password-confirmation'."},
#  {'instruction': 'Who is allowed to access the ForgotPasswordController?',
#   'response': "Access to the ForgotPasswordController is limited to guest users only, as the controller applies the 'guest' middleware in its constructor."},
#  {'instruction': 'Cine are acces la ForgotPasswordController?',
#   'response': "Accesul la ForgotPasswordController este limitat doar pentru utilizatorii neautentificați, deoarece controllerul aplică middleware-ul 'guest' în constructorul său."},
#  {'instruction': 'Explain the overall purpose of the LoginController.',
#   'response': 'The LoginController handles user authentication, managing both standard and social login methods. It uses the AuthenticatesUsers trait to provide common authentication functions and directs users to the appropriate dashboard based on their access level and account status.'},
#  {'instruction': 'Explică scopul general al LoginController-ului.',
#   'response': 'LoginController-ul se ocupă de autentificarea utilizatorilor, gestionând atât metodele standard de autentificare, cât și autentificarea prin rețele sociale. Acesta folosește trăsătura AuthenticatesUsers pentru a oferi funcții comune de autentificare și redirecționează utilizatorii către dashboard-ul corespunzător în funcție de nivelul de acces și starea contului.'},
#  {'instruction': 'What does the __construct method do in this controller?',
#   'response': "The __construct method applies the 'guest' middleware to all actions except 'logout'. This ensures that only non-authenticated users can access the login methods, thereby preventing logged-in users from accessing the login page."},
#  {'instruction': 'Ce face metoda __construct în acest controller?',
#   'response': "Metoda __construct aplică middleware-ul 'guest' tuturor acțiunilor, cu excepția metodei 'logout'. Acest lucru asigură că doar utilizatorii neautentificați pot accesa metodele de login, prevenind astfel accesul utilizatorilor deja autentificați la pagina de login."},
#  {'instruction': 'Describe how the authenticated method handles user redirection after login.',
#   'response': "After a successful login, the authenticated method first checks if the user's account is activated. If not, it logs the user out and redirects them to a candidate signup code validation page. If the account is active, it then checks the user's access level and log step to redirect them to the proper dashboard: candidates go to their dashboard, companies to the company dashboard, admins to the admin dashboard, and so on."},
#  {'instruction': 'Descrie cum metoda authenticated gestionează redirecționarea utilizatorilor după autentificare.',
#   'response': 'După un login reușit, metoda authenticated verifică mai întâi dacă contul utilizatorului este activat. Dacă nu este, utilizatorul este deconectat și redirecționat către pagina de validare a codului de înscriere pentru candidați. Dacă contul este activ, metoda verifică nivelul de acces și pasul de logare al utilizatorului pentru a-l redirecționa către dashboard-ul potrivit: candidații ajung la dashboard-ul lor, companiile la dashboard-ul companiei, administratorii la dashboard-ul de admin etc.'},
#  {'instruction': 'What is the purpose of the username_login method?',
#   'response': 'The username_login method allows users to log in using either their username or email along with their password. It validates the provided credentials, checks them against the stored values, and enforces recaptcha verification after several failed attempts to enhance security.'},
#  {'instruction': 'Care este scopul metodei username_login?',
#   'response': 'Metoda username_login permite utilizatorilor să se autentifice folosind fie numele de utilizator, fie adresa de e-mail, împreună cu parola. Aceasta validează acreditările furnizate, le compară cu valorile stocate și impune verificarea recaptcha după mai multe încercări eșuate pentru a spori securitatea.'},
#  {'instruction': 'How does the controller handle recaptcha verification?',
#   'response': 'If the recaptcha status is enabled and a user has made more than two unsuccessful login attempts, the controller sends a verification request to Google’s recaptcha API. If the recaptcha validation fails, the user is logged out, and an error message is shown, prompting them to try again.'},
#  {'instruction': 'Cum gestionează controller-ul verificarea recaptcha?',
#   'response': 'Dacă recaptcha este activat și un utilizator a făcut mai mult de două încercări eșuate de autentificare, controller-ul trimite o cerere de verificare către API-ul recaptcha al Google. Dacă validarea recaptcha eșuează, utilizatorul este deconectat, iar un mesaj de eroare este afișat, solicitându-i să încerce din nou.'},
#  {'instruction': 'What role do social login methods play in this controller?',
#   'response': "The controller supports social logins via providers such as Facebook, Twitter, LinkedIn, Google, and Apple. For each provider, it provides a method to redirect users to the provider's authentication page and another to handle the callback. Private methods, social_login and social_register, process the data returned from these providers to log in existing users or register new ones."},
#  {'instruction': 'Ce rol au metodele de autentificare socială în acest controller?',
#   'response': 'Controller-ul suportă autentificarea prin rețele sociale prin furnizori precum Facebook, Twitter, LinkedIn, Google și Apple. Pentru fiecare furnizor, există o metodă care redirecționează utilizatorii către pagina de autentificare a furnizorului și alta pentru a gestiona callback-ul. Metodele private social_login și social_register procesează datele returnate de acești furnizori pentru a autentifica utilizatorii existenți sau pentru a înregistra noi utilizatori.'},
#  {'instruction': 'How does the controller ensure that users are authenticated properly when using social login?',
#   'response': "For social logins, after the user is redirected back from the provider, the controller retrieves the social user's information and checks if an account with that email exists. If the account exists and is active, it logs the user in; otherwise, it may prompt for registration or display an error if the account isn’t activated."},
#  {'instruction': 'Cum asigură controller-ul că utilizatorii sunt autentificați corect atunci când folosesc autentificarea socială?',
#   'response': 'Pentru autentificarea socială, după ce utilizatorul este redirecționat înapoi de la furnizor, controller-ul preia informațiile utilizatorului social și verifică dacă există un cont cu acea adresă de e-mail. Dacă contul există și este activ, utilizatorul este autentificat; altfel, poate fi solicitată înregistrarea sau se va afișa un mesaj de eroare dacă contul nu este activat.'}]
